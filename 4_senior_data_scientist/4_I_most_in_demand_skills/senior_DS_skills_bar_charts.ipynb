# %%
# Read the csv file
import pandas as pd
file_path = 'data/senior_DS_skills.csv'
# Read the first 10 lines of the CSV file, including the header
df = pd.read_csv(file_path,nrows=10) #nrows = Number of rows to read from the start of the file. The counting starts at 1.
df
# Out:
#    skill_name  senior_ds_skill_count
# 0      python                  25996
# 1         sql                  18661
# 2           r                  12772
# 3         aws                   7468
# 4       spark                   6638
# 5         sas                   6292
# 6     tableau                   5959
# 7       azure                   5529
# 8  tensorflow                   5068
# 9     pytorch                   4386

# %%
# Change to ascending order (the graph is populated from bottom up)
import matplotlib.pyplot as plt
import numpy as np

sorted_df = df.sort_values(by='senior_ds_skill_count', ascending=True)

# Calculate the percentage for each skill (based on the senior_ds_skill_count of each skill)
total_job_postings = 37_076
sorted_df['percentage'] = ( (sorted_df['senior_ds_skill_count'] / total_job_postings) * 100 )

# Horizontal Bar Chart Design

# Figure Size & Palette
plt.figure(figsize=(10, 6))
# Create a color gradient scheme for the different skills
gradient_colors = plt.cm.Blues(np.linspace(0.5, 1.1, 10))  # Blue gradient

# Create the horizontal bar chart
plt.barh(sorted_df['skill_name'], sorted_df['percentage'],color=gradient_colors)

# Add labels and title 
plt.xlabel('Percentage of Senior Data Scientist Job Postings (%)')
plt.title('Demand for Skills for the Senior Data Scientist Role')

# Display percentage values on the bars
for index, value in enumerate(sorted_df['percentage']): # enumerate() returns the index and value for each entry in the 'percentage' column
    plt.text(value + 0.5, index, f'{value:.1f}%', va='center') #For each skill it places a text label on the plot
    # X-Axis Position = value + 0.5 (to offset the text from the bar)
    # Y-Axis Position = index (at the position of each skill on the y-axis)
    #Label = f'{value:.1f}%' (percentage formatted to 1 decimal place followed by a percent sign)
    #Alignment = va='center' (center the text vertically relative to its y-coordinate)

# Show the plot
plt.xlim(0, max(sorted_df['percentage']) + 5)  # Adjust x-axis limit for better visibility
plt.grid(axis='x', linestyle='--', alpha=0.7) #Grid along the x-axis, dashed lines, and transparency level to 0.7 (not fully opaque)
plt.tight_layout()  # Adjust layout to prevent clipping of labels (optimizes the layout of the elements within the figure)
plt.savefig("assets/senior_DS_skills.pdf", format='pdf', dpi=300, bbox_inches='tight') #tight layout around the figure (ensures that any extra whitespace around the figure is minimized when saving it)
plt.show()

# %%
# Read the csv file
import pandas as pd
file_path = 'data/senior_DS_skills_where.csv'
df = pd.read_csv(file_path)
df
# Out:
#      skill_name  senior_ds_skill_count
# 0           sas                   6292
# 1        pandas                   3614
# 2        hadoop                   3534
# 3         excel                   3285
# 4  scikit-learn                   3244
# 5          java                   3135
# 6           git                   2963
# 7      power bi                   2788
# 8         numpy                   2510
# 9            go                   2102

# %%
# Change to ascending order (the graph is populated from bottom up)
import matplotlib.pyplot as plt
import numpy as np

sorted_df = df.sort_values(by='senior_ds_skill_count', ascending=True)

# Calculate the percentage for each skill (based on the senior_ds_skill_count of each skill)
total_job_postings = 37_076
sorted_df['percentage'] = ( (sorted_df['senior_ds_skill_count'] / total_job_postings) * 100 )

# Horizontal Bar Chart Design

# Figure Size & Palette
plt.figure(figsize=(10, 6))
gradient_colors = plt.cm.Blues(np.linspace(0.5, 1.1, 10))  # Blue gradient
# Create a color gradient scheme for the different skills

# Create the horizontal bar chart
plt.barh(sorted_df['skill_name'], sorted_df['percentage'],color=gradient_colors)

# Add labels and title 
plt.xlabel('Percentage of Senior Data Scientist Job Postings (%)')
plt.title('Demand for Unaddressed Skills for the Senior Data Scientist Role')

# Display percentage values on the bars
for index, value in enumerate(sorted_df['percentage']): # enumerate() returns the index and value for each entry in the 'percentage' column
    plt.text(value + 0.5, index, f'{value:.1f}%', va='center') #For each skill it places a text label on the plot
    # X-Axis Position = value + 0.5 (to offset the text from the bar)
    # Y-Axis Position = index (at the position of each skill on the y-axis)
    #Label = f'{value:.1f}%' (percentage formatted to 1 decimal place followed by a percent sign)
    #Alignment = va='center' (center the text vertically relative to its y-coordinate)

# Show the plot
plt.xlim(0, max(sorted_df['percentage']) + 5)  # Adjust x-axis limit for better visibility
plt.grid(axis='x', linestyle='--', alpha=0.7) #Grid along the x-axis, dashed lines, and transparency level to 0.7 (not fully opaque)
plt.tight_layout()  # Adjust layout to prevent clipping of labels (optimizes the layout of the elements within the figure)
plt.savefig("assets/senior_DS_skills_where.pdf", format='pdf', dpi=300, bbox_inches='tight') #tight layout around the figure (ensures that any extra whitespace around the figure is minimized when saving it)
plt.show()
